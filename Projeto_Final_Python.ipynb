# %% [markdown]
# # **Título:** Análise de dados de crédito para facilitar a identificação de clientes inadimplentes.

# %% [markdown]
# Nesse notebook faremos a análise de dados de crédito com o intuito de encontrar parâmetros que facilitem a identificação de possiveis clientes inadimplentes.

# %% [markdown]
# ## 1\. Importando a biblioteca

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ---

# %% [markdown]
# ## 2\. Exploração dos dados

# %% [markdown]
# - **Carregando os dados**

# %%
df = pd.read_csv('https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/develop/dataset/credito.csv', na_values='na')

# %%
df.head(n=10)
# Out:
#           id  default  idade sexo  dependentes         escolaridade  \
# 0  768805383        0     45    M            3         ensino medio
# 1  818770008        0     49    F            5             mestrado
# 2  713982108        0     51    M            3             mestrado
# 3  769911858        0     40    F            4         ensino medio
# 4  709106358        0     40    M            3  sem educacao formal
# 5  713061558        0     44    M            2             mestrado
# 6  810347208        0     51    M            4                  NaN
# 7  818906208        0     32    M            0         ensino medio
# 8  710930508        0     37    M            3  sem educacao formal
# 9  719661558        0     48    M            2             mestrado
#
#   estado_civil   salario_anual tipo_cartao  meses_de_relacionamento  \
# 0       casado     $60K - $80K        blue                       39
# 1     solteiro  menos que $40K        blue                       44
# ...

# %% [markdown]
# ### **2.1. Estrutura**

# %% [markdown]
# - **Quantidade de linhas e colunas totais do arquivo**

# %%
df.shape
# Out:
# (10127, 16)

# %% [markdown]
# - **Clientes adimplentes**

# %%
df[df['default'] == 0].shape
# Out:
# (8500, 16)

# %% [markdown]
# - **Clientes inadimplentes**

# %%
df[df['default'] == 1].shape
# Out:
# (1627, 16)

# %% [markdown]
# - **Proporção entre clientes adimplentes e inadimplentes**

# %%
qtd_total, _ = df.shape
qtd_adimplentes, _ = df[df['default'] == 0].shape
qtd_inadimplentes, _ = df[df['default'] == 1].shape

print(f"A proporção de clientes adimplentes é de {round(100 * qtd_adimplentes / qtd_total, 2)}%")
print(f"A proporção de clientes inadimplentes é de {round(100 * qtd_inadimplentes / qtd_total, 2)}%")
# Out:
# A proporção de clientes adimplentes é de 83.93%
# A proporção de clientes inadimplentes é de 16.07%

# %% [markdown]
#   ### **2.2. Schema**

# %% [markdown]
# - **Colunas e seus respectivos tipos de dados**

# %%
df.dtypes
# Out:
# id                          int64
# default                     int64
# idade                       int64
# sexo                       object
# dependentes                 int64
# escolaridade               object
# estado_civil               object
# salario_anual              object
# tipo_cartao                object
# meses_de_relacionamento     int64
# qtd_produtos                int64
# iteracoes_12m               int64
# meses_inativo_12m           int64
# limite_credito             object
# valor_transacoes_12m       object
# qtd_transacoes_12m          int64
# dtype: object

# %% [markdown]
# - **Dados categóricos**

# %%
df.select_dtypes('object').describe().transpose()
# Out:
#                       count unique             top  freq
# sexo                  10127      2               F  5358
# escolaridade           8608      5        mestrado  3128
# estado_civil           9378      3          casado  4687
# salario_anual          9015      5  menos que $40K  3561
# tipo_cartao           10127      4            blue  9436
# limite_credito        10127   9272        1.438,21    11
# valor_transacoes_12m  10127  10035        3.851,51     3

# %% [markdown]
# - **Dados numéricos**

# %%
df.drop('id', axis=1).select_dtypes('number').describe().transpose()
# Out:
#                            count       mean        std   min   25%   50%  \
# default                  10127.0   0.160660   0.367235   0.0   0.0   0.0
# idade                    10127.0  46.325960   8.016814  26.0  41.0  46.0
# dependentes              10127.0   2.346203   1.298908   0.0   1.0   2.0
# meses_de_relacionamento  10127.0  35.928409   7.986416  13.0  31.0  36.0
# qtd_produtos             10127.0   3.812580   1.554408   1.0   3.0   4.0
# iteracoes_12m            10127.0   2.455317   1.106225   0.0   2.0   2.0
# meses_inativo_12m        10127.0   2.341167   1.010622   0.0   2.0   2.0
# qtd_transacoes_12m       10127.0  64.858695  23.472570  10.0  45.0  67.0
#
#                           75%    max
# default                   0.0    1.0
# idade                    52.0   73.0
# dependentes               3.0    5.0
# meses_de_relacionamento  40.0   56.0
# qtd_produtos              5.0    6.0
# iteracoes_12m             3.0    6.0
# meses_inativo_12m         3.0    6.0
# ...

# %% [markdown]
# ### **2.3. Dados faltantes**

# %%
df.isna().any()
# Out:
# id                         False
# default                    False
# idade                      False
# sexo                       False
# dependentes                False
# escolaridade                True
# estado_civil                True
# salario_anual               True
# tipo_cartao                False
# meses_de_relacionamento    False
# qtd_produtos               False
# iteracoes_12m              False
# meses_inativo_12m          False
# limite_credito             False
# valor_transacoes_12m       False
# qtd_transacoes_12m         False
# dtype: bool

# %% [markdown]
# - **Estatisticas dados faltantes**

# %%
def stats_dados_faltantes(df: pd.DataFrame) -> None:
  stats_dados_faltantes = []
  for col in df.columns:
    if df[col].isna().any():
      qtd, _ = df[df[col].isna()].shape
      total, _ = df.shape
      dict_dados_faltantes = {col: {'quantidade': qtd, 'porcentagem': round(100 * qtd/total, 2)}}
      stats_dados_faltantes.append(dict_dados_faltantes)

  for stat in stats_dados_faltantes:
    print(stat)

# %% [markdown]
# - **Estatisticas dados faltantes totais**

# %%
stats_dados_faltantes(df=df)
# Out:
# {'escolaridade': {'quantidade': 1519, 'porcentagem': 15.0}}
# {'estado_civil': {'quantidade': 749, 'porcentagem': 7.4}}
# {'salario_anual': {'quantidade': 1112, 'porcentagem': 10.98}}

# %% [markdown]
# - **Estatisticas dados faltantes dos clientes adimplentes**

# %%
stats_dados_faltantes(df=df[df['default'] == 0])
# Out:
# {'escolaridade': {'quantidade': 1263, 'porcentagem': 14.86}}
# {'estado_civil': {'quantidade': 620, 'porcentagem': 7.29}}
# {'salario_anual': {'quantidade': 925, 'porcentagem': 10.88}}

# %% [markdown]
# - **Estatisticas dados faltantes dos clientes inadimplentes**

# %%
stats_dados_faltantes(df=df[df['default'] == 1])
# Out:
# {'escolaridade': {'quantidade': 256, 'porcentagem': 15.73}}
# {'estado_civil': {'quantidade': 129, 'porcentagem': 7.93}}
# {'salario_anual': {'quantidade': 187, 'porcentagem': 11.49}}

# %% [markdown]
# ---

# %% [markdown]
# ## 3\. Transformação e limpeza de dados

# %% [markdown]
# ### **3.1. Correção de Schema**

# %%
df[['limite_credito', 'valor_transacoes_12m']].dtypes
# Out:
# limite_credito          object
# valor_transacoes_12m    object
# dtype: object

# %%
df[['limite_credito', 'valor_transacoes_12m']].head(n=5)
# Out:
#   limite_credito valor_transacoes_12m
# 0      12.691,51             1.144,90
# 1       8.256,96             1.291,45
# 2       3.418,56             1.887,72
# 3       3.313,03             1.171,56
# 4       4.716,22               816,08

# %% [markdown]
# - **Função lambda para limpar os dados e teste da função através do método map**

# %%
fn = lambda valor: float(valor.replace(".", "").replace(",", "."))

valores_originais = ['12.691,51', '8.256,96', '3.418,56', '3.313,03', '4.716,22']
valores_limpos = list(map(fn, valores_originais))

print(valores_originais)
print(valores_limpos)
# Out:
# ['12.691,51', '8.256,96', '3.418,56', '3.313,03', '4.716,22']
# [12691.51, 8256.96, 3418.56, 3313.03, 4716.22]

# %% [markdown]
# - **Aplicação da função lambada às colunas de interesse**

# %%
df['valor_transacoes_12m'] = df['valor_transacoes_12m'].apply(fn)
df['limite_credito'] = df['limite_credito'].apply(fn)

# %% [markdown]
# - **Visualizando o resultado**

# %%
df.dtypes
# Out:
# id                           int64
# default                      int64
# idade                        int64
# sexo                        object
# dependentes                  int64
# escolaridade                object
# estado_civil                object
# salario_anual               object
# tipo_cartao                 object
# meses_de_relacionamento      int64
# qtd_produtos                 int64
# iteracoes_12m                int64
# meses_inativo_12m            int64
# limite_credito             float64
# valor_transacoes_12m       float64
# qtd_transacoes_12m           int64
# dtype: object

# %% [markdown]
# - **Atributos categóricos**

# %%
df.select_dtypes('object').describe().transpose()
# Out:
#                count unique             top  freq
# sexo           10127      2               F  5358
# escolaridade    8608      5        mestrado  3128
# estado_civil    9378      3          casado  4687
# salario_anual   9015      5  menos que $40K  3561
# tipo_cartao    10127      4            blue  9436

# %% [markdown]
# - **Atributos numéricos**

# %%
df.drop('id', axis=1).select_dtypes('number').describe().transpose()
# Out:
#                            count         mean          std      min       25%  \
# default                  10127.0     0.160660     0.367235     0.00     0.000
# idade                    10127.0    46.325960     8.016814    26.00    41.000
# dependentes              10127.0     2.346203     1.298908     0.00     1.000
# meses_de_relacionamento  10127.0    35.928409     7.986416    13.00    31.000
# qtd_produtos             10127.0     3.812580     1.554408     1.00     3.000
# iteracoes_12m            10127.0     2.455317     1.106225     0.00     2.000
# meses_inativo_12m        10127.0     2.341167     1.010622     0.00     2.000
# limite_credito           10127.0  8632.440165  9088.788041  1438.00  2555.355
# valor_transacoes_12m     10127.0  4404.583047  3397.128078   510.16  2155.825
# qtd_transacoes_12m       10127.0    64.858695    23.472570    10.00    45.000
#
#                              50%        75%       max
# default                     0.00      0.000      1.00
# ...

# %% [markdown]
# ### **3.2 Remoção de dados faltantes**

# %%
df.dropna(inplace=True)

# %% [markdown]
# - **Revendo a estrutura dos dados**

# %%
df.shape
# Out:
# (7081, 16)

# %%
df[df['default'] == 0].shape
# Out:
# (5968, 16)

# %%
df[df['default'] == 1].shape
# Out:
# (1113, 16)

# %% [markdown]
# - **Visualização dos resultados**

# %%
qtd_total_novo, _ = df.shape
qtd_adimplentes_novo, _ = df[df['default'] == 0].shape
qtd_inadimplentes_novo, _ = df[df['default'] == 1].shape

# %%
print(f"A proporcão adimplentes ativos é de {round(100 * qtd_adimplentes / qtd_total, 2)}%")
print(f"A nova proporcão de clientes adimplentes é de {round(100 * qtd_adimplentes_novo / qtd_total_novo, 2)}%")
print("")
print(f"A proporcão clientes inadimplentes é de {round(100 * qtd_inadimplentes / qtd_total, 2)}%")
print(f"A nova proporcão de clientes inadimplentes é de {round(100 * qtd_inadimplentes_novo / qtd_total_novo, 2)}%")
# Out:
# A proporcão adimplentes ativos é de 83.93%
# A nova proporcão de clientes adimplentes é de 84.28%
#
# A proporcão clientes inadimplentes é de 16.07%
# A nova proporcão de clientes inadimplentes é de 15.72%

# %% [markdown]
# Como podemos observar, a remoção dos dados faltantes não ocasionou em uma diferença significativa nas proporções dos clientes adimplentes e inadimplentes, não prejudicando assim nossas futuras análises.

# %% [markdown]
# ## 4\. Visualização de dados

# %%
sns.set_style("whitegrid")

# %%
df_adimplente = df[df['default'] == 0]

# %%
df_inadimplente = df[df['default'] == 1]

# %% [markdown]
# ### **4.1. Visualizações dos dados categóricos**

# %%
df.select_dtypes('object').head(n=5)
# Out:
#   sexo         escolaridade estado_civil   salario_anual tipo_cartao
# 0    M         ensino medio       casado     $60K - $80K        blue
# 1    F             mestrado     solteiro  menos que $40K        blue
# 2    M             mestrado       casado    $80K - $120K        blue
# 4    M  sem educacao formal       casado     $60K - $80K        blue
# 5    M             mestrado       casado     $40K - $60K        blue

# %% [markdown]
#  - Escolaridade

# %%
coluna = 'escolaridade'
titulos = ['Escolaridade dos Clientes', 'Escolaridade dos Clientes Adimplentes', 'Escolaridade dos Clientes Inadimplentes']

eixo = 0
max_y = 0
max = df.select_dtypes('object').describe()[coluna]['freq'] * 1.1

figura, eixos = plt.subplots(1,3, figsize=(20, 5), sharex=True)

for dataframe in [df, df_adimplente, df_inadimplente]:

  df_to_plot = dataframe[coluna].value_counts().to_frame()
  df_to_plot.rename(columns={coluna: 'frequencia_absoluta'}, inplace=True)
  df_to_plot[coluna] = df_to_plot.index
  df_to_plot.sort_values(by=[coluna], inplace=True)
  df_to_plot.sort_values(by=[coluna])

  f = sns.barplot(x=df_to_plot[coluna], y=df_to_plot['frequencia_absoluta'], ax=eixos[eixo])
  f.set(title=titulos[eixo], xlabel=coluna.capitalize(), ylabel='Frequência Absoluta')
  f.set_xticklabels(labels=f.get_xticklabels(), rotation=90)

  _, max_y_f = f.get_ylim()
  max_y = max_y_f if max_y_f > max_y else max_y
  f.set(ylim=(0, max_y))

  eixo += 1

figura.show()

# %% [markdown]
# - Salário Anual

# %%
coluna = 'salario_anual'
titulos = ['Salário Anual dos Clientes', 'Salário Anual dos Clientes Adimplentes', 'Salário Anual dos Clientes Inadimplentes']

eixo = 0
max_y = 0
figura, eixos = plt.subplots(1,3, figsize=(20, 5), sharex=True)

for dataframe in [df, df_adimplente, df_inadimplente]:

  df_to_plot = dataframe[coluna].value_counts().to_frame()
  df_to_plot.rename(columns={coluna: 'frequencia_absoluta'}, inplace=True)
  df_to_plot[coluna] = df_to_plot.index
  df_to_plot.reset_index(inplace=True, drop=True)
  df_to_plot.sort_values(by=[coluna], inplace=True)

  f = sns.barplot(x=df_to_plot[coluna], y=df_to_plot['frequencia_absoluta'], ax=eixos[eixo])
  f.set(title=titulos[eixo], xlabel=coluna.capitalize(), ylabel='Frequência Absoluta')
  f.set_xticklabels(labels=f.get_xticklabels(), rotation=90)
  _, max_y_f = f.get_ylim()
  max_y = max_y_f if max_y_f > max_y else max_y
  f.set(ylim=(0, max_y))
  eixo += 1

figura.show()

# %% [markdown]
# - Estado civil

# %%
coluna = 'estado_civil'
titulos = ['Estado Civil dos Clientes', 'Estado Civil dos Clientes Adimplentes', 'Estado Civil dos Clientes Inadimplentes']

eixo = 0
max_y = 0
figura, eixos = plt.subplots(1,3, figsize=(20, 5), sharex=True)

for dataframe in [df, df_adimplente, df_inadimplente]:

  df_to_plot = dataframe[coluna].value_counts().to_frame()
  df_to_plot.rename(columns={coluna: 'frequencia_absoluta'}, inplace=True)
  df_to_plot[coluna] = df_to_plot.index
  df_to_plot.reset_index(inplace=True, drop=True)
  df_to_plot.sort_values(by=[coluna], inplace=True)

  f = sns.barplot(x=df_to_plot[coluna], y=df_to_plot['frequencia_absoluta'], ax=eixos[eixo])
  f.set(title=titulos[eixo], xlabel=coluna.capitalize(), ylabel='Frequência Absoluta')
  f.set_xticklabels(labels=f.get_xticklabels(), rotation=90)
  _, max_y_f = f.get_ylim()
  max_y = max_y_f if max_y_f > max_y else max_y
  f.set(ylim=(0, max_y))
  eixo += 1

figura.show()

# %% [markdown]
# - Tipo de cartão

# %%
coluna = 'tipo_cartao'
titulos = ['Tipo de cartão dos Clientes', 'Tipo de cartão dos Clientes Adimplentes', 'Tipo de cartão dos Clientes Inadimplentes']

eixo = 0
max_y = 0
figura, eixos = plt.subplots(1,3, figsize=(20, 5), sharex=True)

for dataframe in [df, df_adimplente, df_inadimplente]:

  df_to_plot = dataframe[coluna].value_counts().to_frame()
  df_to_plot.rename(columns={coluna: 'frequencia_absoluta'}, inplace=True)
  df_to_plot[coluna] = df_to_plot.index
  df_to_plot.reset_index(inplace=True, drop=True)
  df_to_plot.sort_values(by=[coluna], inplace=True)

  f = sns.barplot(x=df_to_plot[coluna], y=df_to_plot['frequencia_absoluta'], ax=eixos[eixo])
  f.set(title=titulos[eixo], xlabel=coluna.capitalize(), ylabel='Frequência Absoluta')
  f.set_xticklabels(labels=f.get_xticklabels(), rotation=90)
  _, max_y_f = f.get_ylim()
  max_y = max_y_f if max_y_f > max_y else max_y
  f.set(ylim=(0, max_y))
  eixo += 1

figura.show()

# %% [markdown]
# Através da análise dos dados categóricos não foi possivel identificar nenhum padrão que diferenciasse os clientes adimlentes e inadimplentes.

# %% [markdown]
# ### **4.2. Visualizações dos dados numéricos**

# %%
df.drop(['id', 'default'], axis=1).select_dtypes('number').head(n=5)
# Out:
#    idade  dependentes  meses_de_relacionamento  qtd_produtos  iteracoes_12m  \
# 0     45            3                       39             5              3
# 1     49            5                       44             6              2
# 2     51            3                       36             4              0
# 4     40            3                       21             5              0
# 5     44            2                       36             3              2
#
#    meses_inativo_12m  limite_credito  valor_transacoes_12m  qtd_transacoes_12m
# 0                  1        12691.51               1144.90                  42
# 1                  1         8256.96               1291.45                  33
# 2                  1         3418.56               1887.72                  20
# 4                  1         4716.22                816.08                  28
# 5                  1         4010.69               1088.07                  24

# %% [markdown]
# - Quantidade de transações nos últimos 12 meses

# %%
coluna = 'qtd_transacoes_12m'
titulos = ['Qtd. de Transações no Último Ano', 'Qtd. de Transações no Último Ano de Adimplentes', 'Qtd. de Transações no Último Ano de Inadimplentes']

eixo = 0
max_y = 0
figura, eixos = plt.subplots(1,3, figsize=(20, 5), sharex=True)

for dataframe in [df, df_adimplente, df_inadimplente]:

  f = sns.histplot(x=coluna, data=dataframe, stat='count', ax=eixos[eixo]) #sns.histplot método do seaborn que utiliza o histograma
  f.set(title=titulos[eixo], xlabel=coluna.capitalize(), ylabel='Frequência Absoluta')

  _, max_y_f = f.get_ylim()
  max_y = max_y_f if max_y_f > max_y else max_y
  f.set(ylim=(0, max_y))

  eixo += 1

figura.show()

# %% [markdown]
# - Valor das transações nos últimos 12 meses

# %%
coluna = 'valor_transacoes_12m'
titulos = ['Valor das Transações no Último Ano', 'Valor das Transações no Último Ano de Adimplentes', 'Valor das Transações no Último Ano de Inadimplentes']

eixo = 0
max_y = 0
figura, eixos = plt.subplots(1,3, figsize=(20, 5), sharex=True)

for dataframe in [df, df_adimplente, df_inadimplente]:

  f = sns.histplot(x=coluna, data=dataframe, stat='count', ax=eixos[eixo])
  f.set(title=titulos[eixo], xlabel=coluna.capitalize(), ylabel='Frequência Absoluta')

  _, max_y_f = f.get_ylim()
  max_y = max_y_f if max_y_f > max_y else max_y
  f.set(ylim=(0, max_y))

  eixo += 1

figura.show()

# %% [markdown]
# - Valor das transações nos últimos 12 meses x Quantidade de transações nos últimos 12 meses

# %%
f = sns.relplot(x='valor_transacoes_12m', y='qtd_transacoes_12m', data=df, hue='default')
_ = f.set(
    title='Relação entre Valor e Quantidade de Transações no Último Ano',
    xlabel='Valor das Transações no Último Ano',
    ylabel='Quantidade das Transações no Último Ano'
  )

# %% [markdown]
# Como podemos observar em sua totalidade os clientes inadimplentes fizeram uma quantidade inferior a 100 transações no periodo de 12 meses e os valores dessas transações se concentram entre 0 e um valor inferior a R$12.500,00.

# %% [markdown]
# - Limite de crédito

# %%
coluna = 'limite_credito'
titulos = ['Limite de Crédito dos Clientes', 'Limite de Crédito dos Clientes Adimplentes', 'Limite de Crédito dos Clientes Inadimplentes']

eixo = 0
max_y = 0
figura, eixos = plt.subplots(1,3, figsize=(20, 5), sharex=True)

for dataframe in [df, df_adimplente, df_inadimplente]:

  f = sns.histplot(x=coluna, data=dataframe, stat='count', ax=eixos[eixo])
  f.set(title=titulos[eixo], xlabel=coluna.capitalize(), ylabel='Frequência Absoluta')

  _, max_y_f = f.get_ylim()
  max_y = max_y_f if max_y_f > max_y else max_y
  f.set(ylim=(0, max_y))

  eixo += 1

figura.show()

# %% [markdown]
# - Meses inativos nos últimos 12 meses

# %%
coluna = 'meses_inativo_12m'
titulos = ['Meses de inatividade dos Clientes nos últimos 12 meses', 'Meses de inatividade dos Clientes Adimplentes nos últimos 12 meses', 'Meses de inatividade dos Clientes Inadimplentes nos últimos 12 meses']

eixo = 0
max_y = 0
figura, eixos = plt.subplots(1,3, figsize=(20, 5), sharex=True)

for dataframe in [df, df_adimplente, df_inadimplente]:

  f = sns.histplot(x=coluna, data=dataframe, stat='count', ax=eixos[eixo])
  f.set(title=titulos[eixo], xlabel=coluna.capitalize(), ylabel='Frequência Absoluta')

  _, max_y_f = f.get_ylim()
  max_y = max_y_f if max_y_f > max_y else max_y
  f.set(ylim=(0, max_y))

  eixo += 1

figura.show()

# %% [markdown]
# - Limite de crédito dos clientes x Tempo de inatividade dos clientes em um período de 12 meses

# %%
f = sns.relplot(x='limite_credito', y='meses_inativo_12m', data=df, hue='default')
_ = f.set(
    title='Relação entre o limite de crédito e tempo de inatividade dos clientes em um período de 12 meses',
    xlabel='Limite de Crédito dos Clientes',
    ylabel='Meses de inatividade dos Clientes nos últimos 12 meses'
  )

# %% [markdown]
# Através da análise da relação entre o limite de crédito e tempo de inatividade dos clientes em um periodo de 12 meses não foi possível identificar nenhum padrão expressivo que diferenciasse os clientes adimplentes dos inadimplentes.

# %% [markdown]
# - Meses de relacionamento com o cleinte

# %%
coluna = 'meses_de_relacionamento'
titulos = ['Meses de relacionamento dos Clientes', 'Meses de relacionamento dos Clientes Adimplentes', 'Meses de relacionamento dos Clientes Inadimplentes']

eixo = 0
max_y = 0
figura, eixos = plt.subplots(1,3, figsize=(20, 5), sharex=True)

for dataframe in [df, df_adimplente, df_inadimplente]:

  f = sns.histplot(x=coluna, data=dataframe, stat='count', ax=eixos[eixo])
  f.set(title=titulos[eixo], xlabel=coluna.capitalize(), ylabel='Frequência Absoluta')

  _, max_y_f = f.get_ylim()
  max_y = max_y_f if max_y_f > max_y else max_y
  f.set(ylim=(0, max_y))

  eixo += 1

figura.show()

# %% [markdown]
# - Quantidade de produtos adiquiridos pelo cliente

# %%
coluna = 'qtd_produtos'
titulos = ['Quantidade de produtos adiquiridos pelos Clientes', 'Quantidade de produtos adiquiridos pelos Clientes Adimplentes', 'Quantidade de produtos adiquiridos pelos Clientes Inadimplentes']

eixo = 0
max_y = 0
figura, eixos = plt.subplots(1,3, figsize=(20, 5), sharex=True)

for dataframe in [df, df_adimplente, df_inadimplente]:

  f = sns.histplot(x=coluna, data=dataframe, stat='count', ax=eixos[eixo])
  f.set(title=titulos[eixo], xlabel=coluna.capitalize(), ylabel='Frequência Absoluta')

  _, max_y_f = f.get_ylim()
  max_y = max_y_f if max_y_f > max_y else max_y
  f.set(ylim=(0, max_y))

  eixo += 1

figura.show()

# %% [markdown]
# - Meses de relacionamento x Quantidade de produtos adiquiridos

# %%
f = sns.relplot(x='meses_de_relacionamento', y='qtd_produtos', data=df, hue='default')
_ = f.set(
    title='Relação entre o tempo de relacionamento com os clientes e a quantidade de produtos adiquiridos pelos clientes',
    xlabel='Meses de relacionamento dos Clientes',
    ylabel='Quantidade de produtos adiquiridos pelos Clientes'
  )

# %% [markdown]
# A análise da relação entre o tempo de relacionamento com o cliente e a quantidade de produtos adiquiridos pelos clientes não gerou nenhum padrão expressivo que diferenciasse os clientes adimplentes dos inadimplentes.

# %% [markdown]
# - idade dos clientes

# %%
coluna = 'idade'
titulos = ['Idade dos Clientes', 'Idade Clientes Adimplentes', 'Idade dos Clientes Inadimplentes']

eixo = 0
max_y = 0
figura, eixos = plt.subplots(1,3, figsize=(20, 5), sharex=True)

for dataframe in [df, df_adimplente, df_inadimplente]:

  f = sns.histplot(x=coluna, data=dataframe, stat='count', ax=eixos[eixo])
  f.set(title=titulos[eixo], xlabel=coluna.capitalize(), ylabel='Frequência Absoluta')

  _, max_y_f = f.get_ylim()
  max_y = max_y_f if max_y_f > max_y else max_y
  f.set(ylim=(0, max_y))

  eixo += 1

figura.show()

# %% [markdown]
# - Dependentes

# %%
coluna = 'dependentes'
titulos = ['Quantidade de dependentes dos Clientes', 'Quantidade de dependentes dos Clientes Adimplentes', 'Quantidade de dependentes dos Clientes Inadimplentes']

eixo = 0
max_y = 0
figura, eixos = plt.subplots(1,3, figsize=(20, 5), sharex=True)

for dataframe in [df, df_adimplente, df_inadimplente]:

  f = sns.histplot(x=coluna, data=dataframe, stat='count', ax=eixos[eixo])
  f.set(title=titulos[eixo], xlabel=coluna.capitalize(), ylabel='Frequência Absoluta')

  _, max_y_f = f.get_ylim()
  max_y = max_y_f if max_y_f > max_y else max_y
  f.set(ylim=(0, max_y))

  eixo += 1

figura.show()

# %% [markdown]
# - Relação entre a Idade dos clientes x Quantidade de dependentes dos clientes

# %%
f = sns.relplot(x='idade', y='dependentes', data=df, hue='default')
_ = f.set(
    title='Relação entre a idade e a quantidade de dependentes dos clientes',
    xlabel='Idade dos Clientes',
    ylabel='Quantidade de dependentes dos Clientes'
  )

# %% [markdown]
# A análise da relação entre a idade e a quantidade de dependentes dos clientes não nos mostrou nenhum padrão expressivo para podermos diferenciar os clientes adimplentes dos inadimplentes.

# %% [markdown]
# ## 5\. Conclusão da análise

# %% [markdown]
# - Fica claro que os únicos parâmetros que nos fornecem um padrão expressivo o suficiente para diferenciarmos os clientes adimplentes dos inadimplentes são o valor das transações nos últimos 12 meses e a quantidade de transações nos últimos 12 meses.
# - Estabelencendo uma comparação entre os dois parâmetros percebemos que os clientes inadimplentes realizaram uma quantidade inferior a 100 transações no período de 1 ano e as transações tiveram um valor inferior a R$12.500,00.
# - Sendo assim estabelecem-se como bons parâmetros para a identificação de possiveis clientes inadimplentes o valor das transações nos últimos 12 meses, a quantidade de transações nos últimos 12 meses e a relação comparativa entre esses dois dados.
